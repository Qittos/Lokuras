# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Marcos Garza__ <br>
# Market Analyst

# %% [markdown]
# _Data science will come in handy working with market and trade data to recognize and understand patterns and tendencies to improve proficiency and overall income_

# %% [markdown]
# ### The following code is meant to solve a basic sum

# %%
[36 + 11]
# Out:
# [47]

# %% [markdown]
# __My favorite colors__
# 1. Red
# 2. Gray
# 3. Orange
# 4. Tan
# 5. White <br>
#
# __Ingredients to make bread__
# - Flour
# - Water
# - Yeast
# - A bit of Butter or Oil (optional)
# - A bit of Salt <br>
# ![th.jpg](attachment:b15cfe38-546f-4839-981e-56cd73f31f37.jpg)
